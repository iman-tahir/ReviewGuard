# %%
# ==============================
# ReviewGuard: Baseline Models
# ==============================

import joblib
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, classification_report

# ==============================
# Load Data
# ==============================

X_train = joblib.load("../models/X_train.pkl")
X_test = joblib.load("../models/X_test.pkl")
y_train = joblib.load("../models/y_train.pkl")
y_test = joblib.load("../models/y_test.pkl")

print("✅ Data loaded")

# ==============================
# Models
# ==============================

models = {
    "Logistic Regression": joblib.load("../models/review_model.pkl"),
    "Naive Bayes": MultinomialNB(),
    "Linear SVM": LinearSVC()
}

# ==============================
# Train & Evaluate
# ==============================

for name, model in models.items():
    if name != "Logistic Regression":
        model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    print(f"\n🔹 {name}")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# ✅ Data loaded
#
# 🔹 Logistic Regression
# Accuracy: 0.86875
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87       160
#            1       0.86      0.88      0.87       160
#
#     accuracy                           0.87       320
#    macro avg       0.87      0.87      0.87       320
# weighted avg       0.87      0.87      0.87       320
#
#
# 🔹 Naive Bayes
# Accuracy: 0.875
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87       160
#            1       0.85      0.91      0.88       160
#
#     accuracy                           0.88       320
#    macro avg       0.88      0.88      0.87       320
# weighted avg       0.88      0.88      0.87       320
#
#
# 🔹 Linear SVM
# Accuracy: 0.878125
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       160
#            1       0.88      0.88      0.88       160
#
#     accuracy                           0.88       320
#    macro avg       0.88      0.88      0.88       320
# weighted avg       0.88      0.88      0.88       320
